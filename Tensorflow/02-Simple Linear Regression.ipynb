# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Input(x) & Output(y)

# %%
x_data = [1,2,3,4,5]
y_data = [1,2,3,4,5]

# %%
plt.plot(x_data, y_data, 'x')
plt.ylim(0,8)
# Out:
# (0.0, 8.0)
