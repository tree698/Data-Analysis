# %%
import numpy as np

# %%
c = np.array([1,2,3])
print(c.shape)
print(c)
print(c[1])
# Out:
# (3,)
# [1 2 3]
# 2

# %%
r = np.array([[1,2,3]])
print(r.shape)
print(r)
print(r[0,1])
# Out:
# (1, 3)
# [[1 2 3]]
# 2

# %%
a = np.zeros((2,2))
print(a)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
b = np.ones((2,2))
print(b)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
c = np.full((2,2), 7)
print(c)
# Out:
# [[7 7]
#  [7 7]]

# %%
d = np.random.random((2,2))
print(d)
# Out:
# [[0.60237277 0.90913004]
#  [0.99746971 0.75638187]]

# %%
A = np.array([[1,2], [3,4], [5,6]])
print(A)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
A.T
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
B = np.array([[11,12,13,14],[15,16,17,18]])
print(B)
# Out:
# [[11 12 13 14]
#  [15 16 17 18]]

# %%
np.dot(A, B)
# Out:
# array([[ 41,  44,  47,  50],
#        [ 93, 100, 107, 114],
#        [145, 156, 167, 178]])

# %%
A = np.array([[60,5.5,1],[65,5,0],[55,6,1]])
b = np.array([66,70,78])

# %%
eye3 = np.eye(3)
eye3
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
from numpy.linalg import inv

# %%
A_inv = inv(A)
print(A_inv)
# Out:
# [[ 0.08695652  0.00869565 -0.08695652]
#  [-1.13043478  0.08695652  1.13043478]
#  [ 2.         -1.         -1.        ]]

# %%
A.dot(A_inv)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
x = A_inv.dot(b)
x
# Out:
# array([ -0.43478261,  19.65217391, -16.        ])

# %%
from numpy.linalg import solve

# %%
x = solve(A, b)
x
# Out:
# array([ -0.43478261,  19.65217391, -16.        ])
