# %% [markdown]
# # Loading libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Object creation

# %% [markdown]
# ### Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3, 4, np.nan, 6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ### Creating a DataFrame by passing a Numpy array, which a datetime index and labeled columns:

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015

# %% [markdown]
# ### Creating a DataFrame by passing a dict of objects that can be converted to series-like:

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B":pd.Timestamp("20210324"),
        "C":pd.Series(1, index=list(range(4)), dtype="float32"),
        "D":np.array([3]*4, dtype="int32"),
        "E":pd.Categorical(["test", "train", "test", "train"]),
        "F":"foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2021-03-24  1.0  3   test  foo
# 1  1.0 2021-03-24  1.0  3  train  foo
# 2  1.0 2021-03-24  1.0  3   test  foo
# 3  1.0 2021-03-24  1.0  3  train  foo

# %% [markdown]
# ### The columns of the resulting DataFrame have different dtypes:

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815
# 2013-01-05  0.013442  0.175822  0.696630  0.423300

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-5.54930824e-01,  1.06802140e+00,  1.51068490e-01,
#         -1.11521155e+00],
#        [-5.67171017e-01, -8.56653340e-01,  2.26464050e-04,
#          2.13170206e+00],
#        [ 7.73101858e-01,  7.89843031e-02, -1.73103568e+00,
#          4.20933224e-01],
#        [ 5.22557501e-01, -1.59327965e+00, -1.58448598e-01,
#         -1.63281517e+00],
#        [ 1.34420396e-02,  1.75822245e-01,  6.96630249e-01,
#          4.23299624e-01],
#        [-1.20496947e+00,  4.45323561e-01, -3.57431341e-01,
#         -2.37501527e+00]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2021-03-24 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-03-24 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2021-03-24 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-03-24 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.169662 -0.113630 -0.233165 -0.357851
# std    0.745628  0.956144  0.816244  1.654246
# min   -1.204969 -1.593280 -1.731036 -2.375015
# 25%   -0.564111 -0.622744 -0.307686 -1.503414
# 50%   -0.270744  0.127403 -0.079111 -0.347139
# 75%    0.395279  0.377948  0.113358  0.422708
# max    0.773102  1.068021  0.696630  2.131702

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.554931   -0.567171    0.773102    0.522558    0.013442   -1.204969
# B    1.068021   -0.856653    0.078984   -1.593280    0.175822    0.445324
# C    0.151068    0.000226   -1.731036   -0.158449    0.696630   -0.357431
# D   -1.115212    2.131702    0.420933   -1.632815    0.423300   -2.375015

# %% [markdown]
# ### Sorting by axis:

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.115212  0.151068  1.068021 -0.554931
# 2013-01-02  2.131702  0.000226 -0.856653 -0.567171
# 2013-01-03  0.420933 -1.731036  0.078984  0.773102
# 2013-01-04 -1.632815 -0.158449 -1.593280  0.522558
# 2013-01-05  0.423300  0.696630  0.175822  0.013442
# 2013-01-06 -2.375015 -0.357431  0.445324 -1.204969

# %% [markdown]
# ### Sorting by values:

# %%
df.sort_values(by="B", ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815

# %% [markdown]
# # Selection

# %% [markdown]
# ## Getting
#
# ### Selecting a single column, which yields a Series, equivalent to df.A:

# %%
df["A"]
# Out:
# 2013-01-01   -0.554931
# 2013-01-02   -0.567171
# 2013-01-03    0.773102
# 2013-01-04    0.522558
# 2013-01-05    0.013442
# 2013-01-06   -1.204969
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# ### Selecting via [ ], which slices the rows

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933

# %%
df["2013-01-05":"2013-01-07"]
# Out:
#                    A         B         C         D
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015

# %% [markdown]
# ## Selection by label

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015

# %%
df.loc[dates[0]]
# Out:
# A   -0.554931
# B    1.068021
# C    0.151068
# D   -1.115212
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# ### Selecting on multi-axis label:

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -0.554931  1.068021
# 2013-01-02 -0.567171 -0.856653
# 2013-01-03  0.773102  0.078984
# 2013-01-04  0.522558 -1.593280
# 2013-01-05  0.013442  0.175822
# 2013-01-06 -1.204969  0.445324

# %% [markdown]
# ### Showing label slicing, both endpoints are included:

# %%
df.loc["20130102":"20130104",["A","B"]]
# Out:
#                    A         B
# 2013-01-02 -0.567171 -0.856653
# 2013-01-03  0.773102  0.078984
# 2013-01-04  0.522558 -1.593280

# %% [markdown]
# Reduction in the dimensions of the returned object:

# %%
df.loc["20130102",["A","B"]]
# Out:
# A   -0.567171
# B   -0.856653
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# ### For getting a scalar value:

# %%
df.loc[dates[0], "A"]
# Out:
# -0.5549308242831619

# %% [markdown]
# ### For getting fast access to a scalar (equivalent to the prior method):

# %%
df.at[dates[0], "A"]
# Out:
# -0.5549308242831619

# %% [markdown]
# ## Selection by position

# %% [markdown]
# ### Select via the position of the passed integers:

# %%
df.iloc[3]
# Out:
# A    0.522558
# B   -1.593280
# C   -0.158449
# D   -1.632815
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# ### By integer slices, acting similar to numpy/Python:

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.522558 -1.593280
# 2013-01-05  0.013442  0.175822

# %% [markdown]
# ### By lists of interger position locations, similar to the Numpy/Python style:

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.567171  0.000226
# 2013-01-03  0.773102 -1.731036
# 2013-01-05  0.013442  0.696630

# %% [markdown]
# ### For slicing rows explicitly:

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933

# %% [markdown]
# ### For slicing columns explicitly:

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  1.068021  0.151068
# 2013-01-02 -0.856653  0.000226
# 2013-01-03  0.078984 -1.731036
# 2013-01-04 -1.593280 -0.158449
# 2013-01-05  0.175822  0.696630
# 2013-01-06  0.445324 -0.357431

# %% [markdown]
# ### For getting a value explicitly:

# %%
df.iloc[1,1]
# Out:
# -0.8566533399230499

# %% [markdown]
# ### For getting fast access to a scalar (equivalent to the prior method):

# %%
df.iat[1,1]
# Out:
# -0.8566533399230499

# %% [markdown]
# ## Boolean indexing

# %% [markdown]
# ### Using a single column's values to select data:

# %%
df["A"] > 0
# Out:
# 2013-01-01    False
# 2013-01-02    False
# 2013-01-03     True
# 2013-01-04     True
# 2013-01-05     True
# 2013-01-06    False
# Freq: D, Name: A, dtype: bool

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815
# 2013-01-05  0.013442  0.175822  0.696630  0.423300

# %% [markdown]
# ### Selecting valeus from a DataFrame where a boolean condition is met:

# %%
df>0
# Out:
#                 A      B      C      D
# 2013-01-01  False   True   True  False
# 2013-01-02  False  False   True   True
# 2013-01-03   True   True  False   True
# 2013-01-04   True  False  False  False
# 2013-01-05   True   True   True   True
# 2013-01-06  False   True  False  False

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  1.068021  0.151068       NaN
# 2013-01-02       NaN       NaN  0.000226  2.131702
# 2013-01-03  0.773102  0.078984       NaN  0.420933
# 2013-01-04  0.522558       NaN       NaN       NaN
# 2013-01-05  0.013442  0.175822  0.696630  0.423300
# 2013-01-06       NaN  0.445324       NaN       NaN

# %% [markdown]
# ### Using the isin() method for filtering:

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212    one
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702    one
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933    two
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815  three
# 2013-01-05  0.013442  0.175822  0.696630  0.423300   four
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015  three

# %%
df2["E"].isin(["two", "four"])
# Out:
# 2013-01-01    False
# 2013-01-02    False
# 2013-01-03     True
# 2013-01-04    False
# 2013-01-05     True
# 2013-01-06    False
# Freq: D, Name: E, dtype: bool

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933   two
# 2013-01-05  0.013442  0.175822  0.696630  0.423300  four

# %% [markdown]
# ## Setting
#
# ### Setting a new column automatically aligns the data by the indexes:

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range("20130101", periods=6))
s1
# Out:
# 2013-01-01    1
# 2013-01-02    2
# 2013-01-03    3
# 2013-01-04    4
# 2013-01-05    5
# 2013-01-06    6
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D  F
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212  1
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702  2
# 2013-01-03  0.773102  0.078984 -1.731036  0.420933  3
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815  4
# 2013-01-05  0.013442  0.175822  0.696630  0.423300  5
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015  6

# %% [markdown]
# ### Setting values by label:

# %%
df.at[dates[2], "A"] = 0
df
# Out:
#                    A         B         C         D  F
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212  1
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702  2
# 2013-01-03  0.000000  0.078984 -1.731036  0.420933  3
# 2013-01-04  0.522558 -1.593280 -0.158449 -1.632815  4
# 2013-01-05  0.013442  0.175822  0.696630  0.423300  5
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015  6

# %% [markdown]
# ### Setting value by position:

# %%
df.iat[3,0] = 0
df
# Out:
#                    A         B         C         D  F
# 2013-01-01 -0.554931  1.068021  0.151068 -1.115212  1
# 2013-01-02 -0.567171 -0.856653  0.000226  2.131702  2
# 2013-01-03  0.000000  0.078984 -1.731036  0.420933  3
# 2013-01-04  0.000000 -1.593280 -0.158449 -1.632815  4
# 2013-01-05  0.013442  0.175822  0.696630  0.423300  5
# 2013-01-06 -1.204969  0.445324 -0.357431 -2.375015  6

# %% [markdown]
# ### Setting by assing with a NumPy arrary:

# %%
df.loc[:, "D"] = np.array([5]*len(df))
df
# Out:
#                    A         B         C  D  F
# 2013-01-01 -0.554931  1.068021  0.151068  5  1
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2
# 2013-01-03  0.000000  0.078984 -1.731036  5  3
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4
# 2013-01-05  0.013442  0.175822  0.696630  5  5
# 2013-01-06 -1.204969  0.445324 -0.357431  5  6

# %%
len(df)
# Out:
# 6

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C  D  F
# 2013-01-01 -0.554931  1.068021  0.151068  5  1
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2
# 2013-01-03  0.000000  0.078984 -1.731036  5  3
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4
# 2013-01-05  0.013442  0.175822  0.696630  5  5
# 2013-01-06 -1.204969  0.445324 -0.357431  5  6

# %%
df2[df2 > 0]
# Out:
#                    A         B         C  D  F
# 2013-01-01       NaN  1.068021  0.151068  5  1
# 2013-01-02       NaN       NaN  0.000226  5  2
# 2013-01-03       NaN  0.078984       NaN  5  3
# 2013-01-04       NaN       NaN       NaN  5  4
# 2013-01-05  0.013442  0.175822  0.696630  5  5
# 2013-01-06       NaN  0.445324       NaN  5  6

# %%
-df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.554931 -1.068021 -0.151068 -5.0 -1.0
# 2013-01-02  0.567171  0.856653 -0.000226 -5.0 -2.0
# 2013-01-03 -0.000000 -0.078984  1.731036 -5.0 -3.0
# 2013-01-04 -0.000000  1.593280  0.158449 -5.0 -4.0
# 2013-01-05 -0.013442 -0.175822 -0.696630 -5.0 -5.0
# 2013-01-06  1.204969 -0.445324  0.357431 -5.0 -6.0

# %%
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D  F
# 2013-01-01 -0.554931 -1.068021 -0.151068 -5 -1
# 2013-01-02 -0.567171 -0.856653 -0.000226 -5 -2
# 2013-01-03  0.000000 -0.078984 -1.731036 -5 -3
# 2013-01-04  0.000000 -1.593280 -0.158449 -5 -4
# 2013-01-05 -0.013442 -0.175822 -0.696630 -5 -5
# 2013-01-06 -1.204969 -0.445324 -0.357431 -5 -6

# %% [markdown]
# # Missing data
#
# ### pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %% [markdown]
# ### Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1
# Out:
#                    A         B         C  D  F   E
# 2013-01-01 -0.554931  1.068021  0.151068  5  1 NaN
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2 NaN
# 2013-01-03  0.000000  0.078984 -1.731036  5  3 NaN
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4 NaN

# %%
df1.loc[dates[0]:dates[1], "E"] = 1
df1
# Out:
#                    A         B         C  D  F    E
# 2013-01-01 -0.554931  1.068021  0.151068  5  1  1.0
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2  1.0
# 2013-01-03  0.000000  0.078984 -1.731036  5  3  NaN
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4  NaN

# %% [markdown]
# ### To drop any rows that have missing data:

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D  F    E
# 2013-01-01 -0.554931  1.068021  0.151068  5  1  1.0
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2  1.0

# %% [markdown]
# ### Filling missing data:

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  F    E
# 2013-01-01 -0.554931  1.068021  0.151068  5  1  1.0
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2  1.0
# 2013-01-03  0.000000  0.078984 -1.731036  5  3  5.0
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4  5.0

# %%
df1.loc[:,["E"]].fillna(value=5)
# Out:
#               E
# 2013-01-01  1.0
# 2013-01-02  1.0
# 2013-01-03  5.0
# 2013-01-04  5.0

# %% [markdown]
# ### To get the boolean mask where values are nan:

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False  False  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df1.isna()
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False  False  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# # Operations

# %% [markdown]
# ## Stats
#
# Operations in general exclude missing data

# %%
df.mean()
# Out:
# A   -0.385605
# B   -0.113630
# C   -0.233165
# D    5.000000
# F    3.500000
# dtype: float64

# %% [markdown]
# ### Same operation on the other axis:

# %%
df.mean(1)
# Out:
# 2013-01-01    1.332832
# 2013-01-02    1.115280
# 2013-01-03    1.269590
# 2013-01-04    1.449654
# 2013-01-05    2.177179
# 2013-01-06    1.976585
# Freq: D, dtype: float64

# %% [markdown]
# ### Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specific dimention:

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %% [markdown]
# ### Subtract a list and Series by axis with operator version.

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.000000 -0.921016 -2.731036  4.0  2.0
# 2013-01-04 -3.000000 -4.593280 -3.158449  2.0  1.0
# 2013-01-05 -4.986558 -4.824178 -4.303370  0.0  0.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.sub(s, axis=1)
# Out:
#             2013-01-01 00:00:00  2013-01-02 00:00:00  2013-01-03 00:00:00  \
# 2013-01-01                  NaN                  NaN                  NaN
# 2013-01-02                  NaN                  NaN                  NaN
# 2013-01-03                  NaN                  NaN                  NaN
# 2013-01-04                  NaN                  NaN                  NaN
# 2013-01-05                  NaN                  NaN                  NaN
# 2013-01-06                  NaN                  NaN                  NaN
#
#             2013-01-04 00:00:00  2013-01-05 00:00:00  2013-01-06 00:00:00   A  \
# 2013-01-01                  NaN                  NaN                  NaN NaN
# 2013-01-02                  NaN                  NaN                  NaN NaN
# 2013-01-03                  NaN                  NaN                  NaN NaN
# 2013-01-04                  NaN                  NaN                  NaN NaN
# 2013-01-05                  NaN                  NaN                  NaN NaN
# 2013-01-06                  NaN                  NaN                  NaN NaN
#
#              B   C   D   F
# 2013-01-01 NaN NaN NaN NaN
# 2013-01-02 NaN NaN NaN NaN
# 2013-01-03 NaN NaN NaN NaN
# 2013-01-04 NaN NaN NaN NaN
# 2013-01-05 NaN NaN NaN NaN
# 2013-01-06 NaN NaN NaN NaN

# %% [markdown]
# ## Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2013-01-01 -0.554931  1.068021  0.151068   5   1
# 2013-01-02 -1.122102  0.211368  0.151295  10   3
# 2013-01-03 -1.122102  0.290352 -1.579741  15   6
# 2013-01-04 -1.122102 -1.302927 -1.738189  20  10
# 2013-01-05 -1.108660 -1.127105 -1.041559  25  15
# 2013-01-06 -2.313629 -0.681781 -1.398990  30  21

# %%
df_score = pd.DataFrame({"L":[51,65,78], "M":[80,90,100]}, index=["A", "B", "C"])
df_score
# Out:
#     L    M
# A  51   80
# B  65   90
# C  78  100

# %%
df_score.apply(np.average, axis=0)
# Out:
# L    64.666667
# M    90.000000
# dtype: float64

# %%
df_score.apply(np.average, axis=1)
# Out:
# A    65.5
# B    77.5
# C    89.0
# dtype: float64

# %%
df
# Out:
#                    A         B         C  D  F
# 2013-01-01 -0.554931  1.068021  0.151068  5  1
# 2013-01-02 -0.567171 -0.856653  0.000226  5  2
# 2013-01-03  0.000000  0.078984 -1.731036  5  3
# 2013-01-04  0.000000 -1.593280 -0.158449  5  4
# 2013-01-05  0.013442  0.175822  0.696630  5  5
# 2013-01-06 -1.204969  0.445324 -0.357431  5  6

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.218412
# B    2.661301
# C    2.427666
# D    0.000000
# F    5.000000
# dtype: float64

# %% [markdown]
# ## Histogramming
